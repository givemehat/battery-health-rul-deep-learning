# %% [markdown]
# # Notebook 02: Deep Learning Model Training & Comparative Benchmarking
# Benchmarking LSTM, GRU, TCN, BiLSTM-Attention, Temporal Transformer, and Proposed Hybrid SOTA.

# %%
import pandas as pd
from tabulate import tabulate
from train_and_benchmark import run_training_and_benchmarks
# Execute full benchmark
# run_training_and_benchmarks()

# %% [markdown]
# ## Comparative Metrics Table

# %%
df_res = pd.read_csv("results/metrics/model_benchmark_comparison.csv")
print(tabulate(df_res, headers="keys", tablefmt="github", floatfmt=".3f"))
