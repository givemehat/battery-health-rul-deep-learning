# %% [markdown]
# # Notebook 03: Cross-Cell & Degradation-Stage Robustness Analysis
# Validating generalizability and failure mode distributions across battery life cycles.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tabulate import tabulate
df_stages = pd.read_csv("results/metrics/degradation_stages_robustness.csv")
print(tabulate(df_stages, headers="keys", tablefmt="github", floatfmt=".3f"))
